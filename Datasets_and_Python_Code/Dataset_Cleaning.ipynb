# %% [markdown]
# # Clean Eurorack Dataset
#
# <br>
#
# Remove any modules by their function, such as 'Blank Panel' or 'Expander'. Drop duplicate modules with same name and manufacturer. Uses a pretty slow and clunky way of detecting and removing duplicates with a panel descriptor, e.g. Make Noise - MATHS (black panel) will get dropped by the original MATHS. Removed modules are merged with the original, to try and obtain more accurate data.
#
# <br>
#
# Nan values can be delt with in this script.

# %%
import numpy as np
import pandas as pd

#string matching
from thefuzz import fuzz

# %%
#load dataset
df = pd.read_csv('1500_most_popular_eurorack_modules_2024_UNCLEANED.csv', index_col=0)
df.head()
# Out:
#                    Name         Manufacturer  \
# 0                Plaits  Mutable instruments
# 1  Pamela's NEW Workout    ALM Busy Circuits
# 2            Morphagene           Make Noise
# 3                 Maths           Make Noise
# 4           Disting mk4      Expert Sleepers
#
#                                            Functions  HP  Depth  +12V (mA)  \
# 0  ['Noise', 'Oscillator', 'Synth Voice', 'Drum',...  12   25.0       50.0
# 1  ['Clock Generator', 'Digital', 'LFO', 'Clock M...   8   22.0       50.0
# 2  ['Sampling', 'Delay', 'Digital', 'Dual/Stereo'...  20   30.0      165.0
# 3  ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 4  ['Effect', 'Quantizer', 'Utility', 'LFO', 'Osc...   4   42.0       51.0
#
#    -12V (mA)  +5V (mA)  Price (€)  Racks  Rating  Votes     Available  \
# 0        5.0       0.0      250.0  62584    4.57  352.0  Discontinued
# 1        1.0       0.0      279.0  55808    4.75  382.0  Discontinued
# 2       20.0       0.0      569.0  49149    4.63  217.0     Available
# 3       50.0       0.0      268.0  49099    4.75  562.0           NaN
# 4       19.0       0.0      189.0  48139    4.48  265.0     Available
#
#    Approved
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0

# %%
#the Make Noise - Maths module is a good example that contains multiple variants
df[df.Name.str.contains('Maths', case=False)]
# Out:
#                                           Name Manufacturer  \
# 3                                        Maths   Make Noise
# 5                          Maths (white knobs)   Make Noise
# 38                         MATHS (black panel)   Make Noise
# 280                                      MATHS   Make Noise
# 311                                      Maths   Make Noise
# 759                 Maths v2 (Grayscale panel)    Grayscale
# 838   20hp Blank Panel (Maths Lightning Bolts)   Make Noise
# 1116          Maths v2 (Grayscale black panel)    Grayscale
#
#                                               Functions  HP  Depth  +12V (mA)  \
# 3     ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 5     ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 38    ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 280                              ['Function Generator']  20   24.0       60.0
# 311   ['Envelope Generator', 'Envelope Follower', 'L...  20   24.0       60.0
# 759   ['Clock Generator', 'CV Modulation', 'Envelope...  20   24.0       60.0
# 838                                     ['Blank Panel']  20    NaN        NaN
# 1116  ['Clock Generator', 'CV Modulation', 'Envelope...  20   24.0       60.0
#
#       -12V (mA)  +5V (mA)  Price (€)  Racks  Rating  Votes     Available  \
# 3          50.0       0.0      268.0  49099    4.75  562.0           NaN
# 5          50.0       0.0      319.0  44616    4.69  176.0     Available
# 38         50.0       0.0      325.0  17400    4.50   42.0     Available
# 280        60.0       0.0      325.0   5771    4.60   98.0  Discontinued
# 311        50.0       0.0      245.0   5335    4.49   83.0  Discontinued
# 759        50.0       NaN      261.0   2517    4.60   15.0           NaN
# 838         NaN       NaN       14.0   2276    4.25    8.0           NaN
# 1116       50.0       0.0      261.0   1707    4.85   13.0     Available
#
#       Approved
# 3            1
# 5            0
# 38           0
# 280          0
# 311          0
# 759          1
# 838          1
# 1116         1

# %%
#Data Cleaning
#---------------------------------------------------------

#drop based on fucntion
#remove blank panels, power modules, and expander modules

#COMMENT OUT IF YOU WANT TO HAVE THESE IN THE DATA SET
df = df[~df.Functions.str.contains('Blank Panel')]
# df = df[~df.Functions.str.contains('Power')]
# df = df[~df.Functions.str.contains('Expander')]


#remove duplicates that share the same name and manufacturer (case insensitive)
#create to column to contain case insensitive name and manufacturer
df['Name Lower'] = df['Name'].str.lower()
df['Manufacturer Lower'] = df['Manufacturer'].str.lower()

#merge modules with same name and manufacturer
df_sum = df.groupby(['Name Lower', 'Manufacturer Lower'], as_index=False).agg({'Racks': 'sum', 'Votes': 'sum', 'Rating': 'mean'})
#sum racks and votes, find mean of rating


#drop duplicates on original df
df = df.drop_duplicates(subset=['Name Lower', 'Manufacturer Lower'], keep='first')

#merg df_sum and df
df = df.merge(df_sum, on=['Name Lower', 'Manufacturer Lower'], how='left')
#replace old info (Old_x) with new (New_y)
df['Racks_x'] = df['Racks_y']
df['Votes_x'] = df['Votes_y']
df['Rating_x'] = round(df['Rating_y'], 2)
#remove unwanted columns
df = df.drop(columns=['Name Lower', 'Manufacturer Lower', 'Racks_y', 'Votes_y', 'Rating_y'])
df = df.rename(columns={'Racks_x': 'Racks', 'Votes_x': 'Votes', 'Rating_x': 'Rating'})

#resort by Racks
df = df.sort_values(by='Racks', ascending=False)
df = df.reset_index(drop=True)

print('Dataset Length:', len(df))
# Out:
# Dataset Length: 1458

# %%
#duplicates persist with different panels
df[df.Name.str.contains('Maths', case=False)]
# Out:
#                                   Name Manufacturer  \
# 1                                Maths   Make Noise
# 5                  Maths (white knobs)   Make Noise
# 38                 MATHS (black panel)   Make Noise
# 742         Maths v2 (Grayscale panel)    Grayscale
# 1089  Maths v2 (Grayscale black panel)    Grayscale
#
#                                               Functions  HP  Depth  +12V (mA)  \
# 1     ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 5     ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 38    ['Attenuator', 'CV Modulation', 'Envelope Foll...  20   24.0       60.0
# 742   ['Clock Generator', 'CV Modulation', 'Envelope...  20   24.0       60.0
# 1089  ['Clock Generator', 'CV Modulation', 'Envelope...  20   24.0       60.0
#
#       -12V (mA)  +5V (mA)  Price (€)  Racks  Rating  Votes  Available  \
# 1          50.0       0.0      268.0  60205    4.61  743.0        NaN
# 5          50.0       0.0      319.0  44616    4.69  176.0  Available
# 38         50.0       0.0      325.0  17400    4.50   42.0  Available
# 742        50.0       NaN      261.0   2517    4.60   15.0        NaN
# 1089       50.0       0.0      261.0   1707    4.85   13.0  Available
#
#       Approved
# 1            1
# 5            0
# 38           0
# 742          1
# 1089         1

# %%
#remove duplicates with panel descriptor

#create new column to store string similarity
df.insert(14, 'Similarity', np.zeros(len(df)))

#sort df by length of name
#original module will have shorter name
df = df.sort_values(by="Name", key=lambda x: x.str.len())
df = df.reset_index(drop=True)

for target_module in range(0, len(df)):

    #slice from target module to end
    dupes = df[target_module:]
    
    #test all modules and find modules with similar names to target
    for search_index in range(0, len(dupes)):
        
        similarity = fuzz.token_set_ratio(df.iloc[target_module, 0], dupes.iloc[search_index, 0])
    
        #disrigard if target and test modules do not share the same manufacturer	
        if df.iloc[target_module, 1] != dupes.iloc[search_index, 1]:
            similarity = 0
    
        dupes.iloc[search_index, 14] = similarity
        
    #drop all duplicate modules that have a similarity score less than threshold
    dupes = dupes[~(dupes['Similarity'] < 95 )]

    #check if dupe df contains more than one row(the target itself)
    if len(dupes) > 1:
        
        #modules that are similar to target and contain panel descriptor
        panel_dupes = dupes[dupes.Name.str.contains('panel', case=False)|dupes.Name.str.contains('black', case=False)
                            |dupes.Name.str.contains('white', case=False)|dupes.Name.str.contains('silver', case=False)
                            |dupes.Name.str.contains('gold', case=False)|dupes.Name.str.contains('edition', case=False)
                            |dupes.Name.str.contains('grey', case=False)]
        
    
        #count how many modules have been dropped
        #used when dropping from df
        modules_dropped = 0
        
        panel_rating = 0
        #loop through all dupe modules containing panel descriptors
        for search_index in range(0, len(panel_dupes)):
            
            #check if target and test module are the same by comparing index
            if panel_dupes.axes[0][search_index] != target_module:
                
                #assume if HP match, modules are the same and can be removed
                if panel_dupes.iloc[search_index, 3] == df.iloc[target_module, 3]:

                    #sum racks to target
                    df.iloc[target_module, 9] += panel_dupes.iloc[search_index, 9]
                    
                    #sum votes 
                    df.iloc[target_module, 11] += panel_dupes.iloc[search_index, 11]
                    
                    #sum panel rating
                    panel_rating += panel_dupes.iloc[search_index, 10]
                    
                    #drop panel dupes from dupes
                    dupes = dupes.drop(panel_dupes.axes[0][search_index])

                    #display which dupe modules have been removed, and by which target module
                    print(df.iloc[panel_dupes.axes[0][search_index]-modules_dropped, 0], 'Dropped by', df.iloc[target_module, 0])
                
                    #drop panel dupe from df
                    df = df.drop(panel_dupes.axes[0][search_index]-modules_dropped)
    
                    #correct index when panel dupes have been dropped for df
                    modules_dropped += 1
                    
                    df = df.reset_index(drop=True)

        df.iloc[target_module, 10] = round((df.iloc[target_module, 10] + panel_rating) / (modules_dropped + 1), 2)
# Out:
# DC (Black Panel) Dropped by DC
# TM (Black Panel) Dropped by TM
# EG (Black Panel) Dropped by EG
# DOT (black panel) Dropped by DOT
# 3:1 (Black Panel) Dropped by 3:1
# Rnd v2 (Black Panel) Dropped by Rnd
# CAT (After Hours panel) Dropped by CAT
# SPA (grandPa Expander) - ALUMINIUM Panel Dropped by SPA
# Ana (Purple Panel) Dropped by ANA
# Nse (Black Panel) Dropped by Nse
# VCO (Black Panel) Dropped by VCO
# S+H (Black Panel) Dropped by S+H
# ABC - Black Dropped by ABC
# Div (Black Panel) Dropped by Div
# MMF (Black Panel) Dropped by MMF
# Arp (Black Panel) Dropped by Arp
# Hat (Black Panel) Dropped by Hat
# Hel (black panel) Dropped by Hel
# Seq (Black Panel) Dropped by Seq
# K-2 - Heinakroon panels Dropped by K-2
# LPF (Black Panel) Dropped by LPF
# LFO v2 (Black Panel) Dropped by LFO
# Clk (Black Panel) Dropped by Clk
# BLD-2 Battleship Grey Dropped by BLD
# Osc (black) Dropped by Osc
# LFO v2 (matte black) Dropped by LFO
# Sol (black panel) Dropped by Sol
# MIX (aluminum panel) Dropped by MIX
# (Black) MIR Dropped by MIR
# STO (white knobs) Dropped by STO
# STO (Black and Gold) Dropped by STO
# VCA (Black Panel) Dropped by VCA
# Mix (Black Panel) Dropped by Mix
# DPO (black panel) Dropped by DPO
# DPO (white knobs) Dropped by DPO
# Nin (black panel) Dropped by Nin
# Poti (black panel) Dropped by Poti
# uLFO Black Dropped by uLFO
# Mult (Love Panel) Dropped by Mult
# Mult (Black Panel) Dropped by Mult
# m666 (original black panel version) Dropped by m666
# Brst (Black Panel) Dropped by Brst
# Skis II - Black Dropped by Skis
# Loop (Black Panel) Dropped by Loop
# (Black) Maze Dropped by Maze
# ATOM (white panel) Dropped by ATOM
# ATOM (plain panel) Dropped by ATOM
# Atom (Magpie Panel) Dropped by ATOM
# QV-L (black) Dropped by QV-L
# Jena (black panel) Dropped by Jena
# Play (Black panel) Dropped by Play
# Trim (Black Panel) Dropped by Trim
# ES-8 Bitwig Edition Dropped by ES-8
# MIX7 (BLACK) Dropped by MIX7
# Tree (Black Panel) Dropped by Tree
# Tree (Purple Panel) Dropped by Tree
# Deva (black panel) Dropped by Deva
# SM-1 (Battleship Grey) Dropped by SM-1
# PH-4 (White) Dropped by PH-4
# Gera (black panel) Dropped by Gera
# Filt (Black) Dropped by Filt
# QMMG (Black & Gold) Dropped by QMMG
# QMMG (Blue/White Knobs) Dropped by QMMG
# Rout (Black Panel) Dropped by Rout
# Comp (Black Panel) Dropped by Comp
# MIDI (Black Panel) Dropped by MIDI
# Hrad (black panel) Dropped by Hrad
# uO_C Black & Gold Panel Dropped by uO_C
# Verb (Black Panel) Dropped by Verb
# RT60 (Black Panel) Dropped by RT60
# Bell (Black Panel) Dropped by Bell
# Cara (Black Magpie Panel) Dropped by CARA
# Antumbra CARA (White Textured Aluminum) Dropped by CARA
# AP-1 (White) Dropped by AP-1
# AP-1 MK2 (Grey) Dropped by AP-1
# AP-1 MK2 (Eggshell white) Dropped by AP-1
# µVCF (old panel) Dropped by µVCF
# Comb (Black Panel) Dropped by Comb
# RG-6 (Grayscale alt panel) Dropped by RG-6
# Kick (Black Panel) Dropped by Kick
# Gait (Gold) Dropped by Gait
# Tune (Black Panel) Dropped by Tune
# ADSR (Black Panel) Dropped by ADSR
# Buff ( Black Panel) Dropped by Buff
# Rene (Limited Edition White) Dropped by Rene
# MSCL (Black Panel) Dropped by MSCL
# KNIT (White Magpie Panel) Dropped by KNIT
# Knit - Magpie black panel Dropped by KNIT
# MA808 (WHITE) Dropped by MA808
# Warna II (black panel) Dropped by Warna
# Mińsk w/(black panel) Dropped by Mińsk
# Merge [Black panel] Dropped by Merge
# Merge [white panel] Dropped by Merge
# VC-SC (Eggshell White) Dropped by VC-SC
# Bloom (Silver Panel) Dropped by Bloom
# Z8000 Black Dropped by Z8000
# Praga (black panel) Dropped by Praga
# Pôles black Dropped by Pôles
# Sofia (black panel) Dropped by Sofia
# MMF-6 (Grayscale alt panel) Dropped by MMF-6
# Logoi Black Dropped by Logoi
# SD808 (WHITE) Dropped by SD808
# Zadar (black panel) Dropped by Zadar
# Pitch (Black Panel) Dropped by Pitch
# CP909 (WHITE) Dropped by CP909
# Bytom (black panel) Dropped by Bytom
# 2xSAM_black Dropped by 2xSAM
# SD909 (WHITE) Dropped by SD909
# (Black) Felix Dropped by Felix
# Volts (Black) Dropped by Volts
# CB808 (WHITE) Dropped by CB808
# MULTS black panel Dropped by Mults
# BD909 (WHITE) Dropped by BD909
# Freez (Black Panel) Dropped by Freez
# Unity (Black Panel) Dropped by Unity
# Avert (Black Panel) Dropped by AVert
# Twist (Black) Dropped by Twist
# Pluck (Black Panel) Dropped by Pluck
# BD808 (WHITE) Dropped by BD808
# MX-4S (White) Dropped by MX-4S
# Quiet (Gold) Dropped by Quiet
# Ciao - Black Dropped by Ciao!
# RS909 (WHITE) Dropped by RS909
# RES-4 (White) Dropped by RES-4
# Maths (white knobs) Dropped by Maths
# MATHS (black panel) Dropped by Maths
# A-312 black Dropped by a-312
# SY0.5 Special Edition Dropped by SY0.5
# Snare (Black Panel) Dropped by Snare
# MMF-2 (Battleship Grey) Dropped by MMF-2
# µTune - black edition Dropped by µTune
# µTune - silver edition Dropped by µTune
# Prism (Silver Panel) Dropped by Prism
# Logic (Black Panel) Dropped by Logic
# VCO-6 Multi Output Oscillator (White) Dropped by VCO-6
# Grain (Black Panel) Dropped by Grain
# U-081 (Custom Black Panel) Dropped by U-081
# Titan Oscillator Black Edition Dropped by Titan
# VM-1S (grey) Dropped by VM-1S
# Vowel (Black Panel) Dropped by Vowel
# Peaks (White / Gold Panel) Dropped by Peaks
# Chipz (Ltd. panel) Dropped by Chipz
# Delay (Black Panel) Dropped by Delay
# Lipsk (black panel) Dropped by Lipsk
# RS808 (WHITE) Dropped by RS808
# Samara II (black panel) Dropped by Samara
# 4xMUTE - black Dropped by 4xMUTE
# Tromsø (Aluminum Panel) Dropped by Tromsø
# Metron (Black) Dropped by METRON
# uGrids (Matte Black Aluminum) Dropped by uGrids
# 3x MIA - black Dropped by 3x MIA
# Spring (Custom Panel) Dropped by Spring
# Tirana II (black panel) Dropped by Tirana
# nRings (black panel) Dropped by nRings
# Pulses Mk II (Black) Dropped by Pulses
# Pulses Mk II (Black Panel) Dropped by Pulses
# Odessa (black panel) Dropped by Odessa
# Splish black panel Dropped by Splish
# nRings (Black) Dropped by nRings
# OPERAT (silver) Dropped by Operat
# Batumi (black panel) Dropped by Batumi
# Karp 鲤 (Black) Dropped by Karp 鲤
# Tallin (black panel) Dropped by Tallin
# Hector (Black Panel) Dropped by Hector
# Kaseta (Black) Dropped by Kaseta
# Rhythm (black panel) Dropped by Rhythm
# Prizma mkII (black) Dropped by Prizma
# Prizma (Modest Panel) Dropped by Prizma
# troika [Black & Gold Panel] Dropped by troika
# FX AID_black Dropped by FX AID
# FX AID (black & gold) Dropped by FX AID
# Grains (new panel) Dropped by Grains
# VCA-2P (white) Dropped by VCA-2P
# Nebulæ (Black Panel) Dropped by Nebulæ
# zSPLIT (black panel) Dropped by zSPLIT
# Phoreo Black Dropped by Phoreo
# Let's Splosh - Seaweed White Magpie Panel Dropped by Splosh
# PanMix - black Dropped by PanMix
# Hermod (Black Panel) Dropped by Hermod
# CTG-VC (Grayscale alt panel) Dropped by CTG-VC
# Timber - Black Dropped by TIMBER
# Messor Silver Dropped by Messor
# Switch (Black Panel) Dropped by Switch
# 6x MIX - black Dropped by 6x MIX
# 3x VCA - black Dropped by 3x VCA
# Drezno (black panel) Dropped by Drezno
# Drezno II (black panel) Dropped by Drezno
# µBurst (silver panel) Dropped by µBurst
# Euclid (Black Panel) Dropped by Euclid
# nRings (Black/Gold) Dropped by nRings
# Triatt (old panel) Dropped by Triatt
# Moskwa II (black panel) Dropped by Moskwa
# Chance (Black Panel) Dropped by Chance
# Octone (Black) Dropped by Octone
# 101-VCF Black Dropped by 101-VCF
# Tuesday Golden Prototype Dropped by Tuesday
# MiniMix(Soulless panel) Dropped by Minimix
# A-174-4 Joy Stick II Black Edition Dropped by A-174-4
# Belgrad (black panel) Dropped by Belgrad
# Rostock (black panel) Dropped by Rostock
# Control (Black) Dropped by Control
# Hatz v2 (silver) Dropped by Hatz v2
# Optomix (black panel) Dropped by Optomix
# Typhoon (white) Dropped by Typhoon
# PM DB25 (Black) Dropped by PM DB25
# V Shape (silver) Dropped by V Shape
# uPlaits (Black) Dropped by uPlaits
# Mr Blue (Black panel) Dropped by Mr Blue
# Poczdam (black panel) Dropped by Poczdam
# Monsoon - Matte Black Aluminum Dropped by Monsoon
# Jam Jam (Silver) Dropped by Jam Jam
# Deviant Black Panel Dropped by Deviant
# Scanned (Silver Panel) Dropped by Scanned
# TriTone_black Dropped by TriTone
# Alter 1/2 (Gold) Dropped by Alter 1
# TOMS909 (WHITE) Dropped by TOMS909
# Timbre! (Magpie Modular panel) Dropped by Timbre!
# ArdCore  silver faceplate Dropped by ArdCore
# VCO 104 (Aluminium Panel) Dropped by VCO 104
# JP6-VCF Aluminum Panel Dropped by JP6-VCF
# Dial-Up Black Panel Dropped by Dial-up
# Bin Seq (Black) Dropped by Bin Seq
# Selecta - reversible panel Dropped by Selecta
# Rampage POCOCHIS edition Dropped by Rampage
# Bizmuth (Black LTD) Dropped by Bizmuth
# VCO-2RM (White) Dropped by VCO-2RM
# Monsoon (black) Dropped by Monsoon
# Typhoon ( Black Panel ) Dropped by Typhoon
# 860 MK2 (GREY) Dropped by 860 MK2
# Cascade (Black Panel) Dropped by Cascade
# Chimera (Black) Dropped by Chimera
# zLINEIN (Black panel) Dropped by zLINEIN
# GЛИТЧ-3 black БК Dropped by GЛИТЧ-3
# GЛИТЧ-3 black СК Dropped by GЛИТЧ-3
# HATS909 (WHITE) Dropped by HATS909
# MMM VCF - black Dropped by MMM VCF
# MMM VCF (bitmud panel) Dropped by MMM VCF
# Synapse (Silver) Dropped by Synapse
# Locutus (black) Dropped by Locutus
# Contour (black panel) Dropped by Contour
# Quadigy (Black panel) Dropped by Quadigy
# Monsoon (White & Gold) Dropped by Monsoon
# Ostrawa (black panel) Dropped by Ostrawa
# Neutron (2.3 panel) Dropped by Neutron
# Neutron (1966 Panel) Dropped by Neutron
# Neutron (101 Ash Panel) Dropped by Neutron
# Neutron (After Hours panel) Dropped by Neutron
# Neutron (Heinakroon Black Panel) Dropped by Neutron
# Neutron (Euroracked Aluminium Panel) Dropped by Neutron
# Neutron w/ Graydon Audio Faceplate (Phosphorescent Black Light Glow Mode) Dropped by Neutron
# Nerdseq Grey Aluminium Front Dropped by Nerdseq
# Nerdseq Grey/Black Aluminium Dropped by Nerdseq
# Nerdseq Black Aluminium Front Dropped by Nerdseq
# Zagrzeb (black panel) Dropped by Zagrzeb
# HATS808 (WHITE) Dropped by HATS808
# Delta-V (old panel) Dropped by Delta-V
# Delta-V (Silver panel) Dropped by Delta-V
# Surface (Silver) Dropped by Surface
# Cascade (Silver) Dropped by Cascade
# Punch V3 (silver) Dropped by PUNCH V3
# modDemix (black panel) Dropped by modDemix
# VCF 2164 (matte black) Dropped by VCF 2164
# Echophon (black panel) Dropped by Echophon
# Echophon (white knobs) Dropped by Echophon
# Overseer (black panel) Dropped by Overseer
# Chord v2 (Silver Panel) Dropped by Chord v2
# Multiple (alum. panel) Dropped by Multiple
# Isolator - black Dropped by Isolator
# Isolator (2022) black Dropped by Isolator
# Isolator (2022) silver Dropped by Isolator
# Grand Terminal (black) Dropped by Terminal
# Grand Terminal (golden) Dropped by Terminal
# Grand Terminal (silver) Dropped by Terminal
# Klasmata Black Dropped by Klasmata
# Tea Kick(Aluminum Panel) Dropped by Tea Kick
# Ephemere (silver panel) Dropped by Ephemere
# Pure LFO (black panel) Dropped by PURE LFO
# Aperture (BLACK) Dropped by Aperture
# Quad AAF (BLACK) Dropped by Quad AAF
# Z4000 NS (Black) Dropped by Z4000 NS
# Quad LFO [Black] Dropped by Quad LFO
# Sarajewo (black panel) Dropped by Sarajewo
# Grainity (Black panel) Dropped by Grainity
# CYMBL909 (WHITE) Dropped by CYMBL909
# 100 Grit (black) Dropped by 100 Grit
# PM Mutes Expander (Black) Dropped by PM Mutes
# Resonate - Magpie Black Panel Dropped by Resonate
# modDemod (Original Panel) Dropped by modDemod
# Polygogo (white panel) Dropped by polygogo
# Lyra8-FX (Black Panel) Dropped by Lyra8-FX
# Fracture (Black) Dropped by Fracture
# Tweakers (Black panel) Dropped by Tweakers
# Koszalin (black panel) Dropped by Koszalin
# Katowice (black panel) Dropped by Katowice
# Two Bits (Black panel) Dropped by Two Bits
# No-Drums 2015 (Grey Faceplate) Dropped by No Drums
# ADDAC207 Intuitive Quantizer (black) Dropped by ADDAC207
# Mixology (Black) Dropped by Mixology
# TRSHMSTR (Black) Dropped by TRSHMSTR
# Cinnamon - Black Dropped by Cinnamon
# Cinnamon (BKMPanel) Dropped by Cinnamon
# Cinnamon (Aluminum Panel) Dropped by Cinnamon
# Pachinko (Black) Dropped by Pachinko
# Quad VCA (Black Panel) Dropped by Quad VCA
# LRMSMSLR (red panel) Dropped by LRMSMSLR
# LRMSMSLR (Black and gold panel) Dropped by LRMSMSLR
# Function (white knobs) Dropped by Function
# Function (2024 Black & Gold) Dropped by Function
# Morpheus (black) Dropped by Morpheus
# 4023 VCF Black Dropped by 4023 VCF
# Sinc Iter (Black) Dropped by Sinc Iter
# Zone B.F. Black Edition Dropped by Zone B.F.
# Kamieniec (black panel) Dropped by Kamieniec
# FX AID XL_black Dropped by FX AID XL
# FX AID XL (black & gold) Dropped by FX AID XL
# Macro VCO Matt Black 2020 Dropped by Macro VCO
# Erbe-Verb (black panel) Dropped by Erbe-Verb
# Erbe-Verb (white knobs) Dropped by Erbe-Verb
# Black VCO2 Dropped by Black VCO
# Black Wavetable VCO Dropped by Black VCO
# Metamorph / Black panel Dropped by Metamorph
# Lapsus Os (Black) Dropped by Lapsus Os
# Listen IO black faceplate Dropped by Listen IO
# Stoicheia Black Dropped by Stoicheia
# Motomouth (black panel) Dropped by Motomouth
# Crossfold (New Panel) Dropped by Crossfold
# Achordion (Black) Dropped by Achordion
# Nano Rand (Black Panel) Dropped by Nano Rand
# Arpitecht (black panel) Dropped by Arpitecht
# Simple EQ (Black Panel) Dropped by Simple EQ
# Dual Borg - Magpie white panel Dropped by DUAL BORG
# Phonogene (black panel) Dropped by Phonogene
# QuantiZer (BLACK) Dropped by QuantiZer
# Black Modulator Dropped by Modulator
# Black Modulator V2 Dropped by Modulator
# Black Modulator v1 Dropped by Modulator
# Quantizer (Vintagelavalamp Black Panel) Dropped by Quantizer
# LED Meter - black Dropped by LED Meter
# PanMix Jr - Black Dropped by PanMix Jr
# Roti Pola (Black) Dropped by Roti Pola
# Threshold (Black Panel) Dropped by Threshold
# Stereomix 2 (Black Panel) Dropped by Stereomix
# Stereomix 2 (Silver Panel) Dropped by Stereomix
# Moon Phase (silver) Dropped by Moon Phase
# Chronoblob - Magpie white panel Dropped by Chronoblob
# Chronoblob (Magpie Modular Panel) Dropped by Chronoblob
# VCA Matrix (Black) Dropped by VCA Matrix
# Pure Noise (black panel) Dropped by PURE Noise
# Timiszoara (black panel) Dropped by Timiszoara
# Golden drum drone bank 14kr Dropped by DRONE BANK
# Chronovore (Black) Dropped by Chronovore
# Vice Virga (Silver) Dropped by Vice Virga
# Eurobuffer (Modular Addict Panel) Dropped by Eurobuffer
# Quadrangle white version Dropped by Quadrangle
# PER|FORMER (Performer alternate panel) Dropped by PER|FORMER
# 4093 CHAOS NAND (black panel) Dropped by CHAOS NAND
# Assimil8or (black) Dropped by Assimil8or
# Algorhythm (black panel) Dropped by Algorhythm
# Viol Ruina (Silver) Dropped by Viol Ruina
# Pura Ruina (Silver) Dropped by Pura Ruina
# NEXT PHASE (silver) Dropped by Next Phase
# Eloquencer (Silver) Dropped by Eloquencer
# FX AID Pro_black Dropped by FX AID Pro
# BitBox 2.0 Black Panel Dropped by Bitbox 2.0
# Bitbox 2.0 Black Panel V2 Dropped by Bitbox 2.0
# CV Trinity – Aluminum Panel Dropped by CV TRINITY
# Soleo Vero (Black) Dropped by Soleo Vero
# Nebulae V2 silver Dropped by Nebulae v2
# Tymp Legio (Silver) Dropped by Tymp Legio
# Seca Ruina (Silver) Dropped by Seca Ruina
# dual xfade_black Dropped by dual xfade
# Muta Jovis (Black) Dropped by Muta Jovis
# MicroGrids (Black Panel) Dropped by MicroGrids
# Kith Ruina (Silver) Dropped by Kith Ruina
# Graphic EQ (Black Panel) Dropped by Graphic EQ
# Quant Gemi (Silver) Dropped by Quant Gemi
# Xer Dualis (Silver) Dropped by Xer Dualis
# Squid Axon - Magpie black panel Dropped by Squid Axon
# Knit Rider Aluminium Panel Dropped by Knit Rider
# Knit Rider Aluminium Panel (Outputs Right) Dropped by Knit Rider
# Data Bender (Silver) Dropped by Data Bender
# Listen Four Black Faceplate Dropped by Listen Four
# Quantus Pax (Silver) Dropped by Quantus Pax
# Varigate 4+ (Black) Dropped by Varigate 4+
# Black VC Clock V2 Dropped by VC Clock V2
# Mini FM Joystick (black) Dropped by FM JOYSTICK
# Mikrophonie (black) Dropped by Mikrophonie
# Mikrophonie (2017 new panel design) Dropped by Mikrophonie
# Sinc Defero (Black) Dropped by Sinc Defero
# Xerest Pola (Black) Dropped by Xerest Pola
# Sinc Bucina (Silver) Dropped by Sinc Bucina
# Varigate 8+ (Black Panel) Dropped by Varigate 8+
# tELHARMONIC (white knobs) Dropped by Telharmonic
# Telharmonic (Black and Gold) Dropped by Telharmonic
# Black Stereo Mixer Dropped by Black Mixer
# Black Stereo Mixer V3 Dropped by Black Mixer
# Black Stereo Mixer V2 Dropped by Black Mixer
# AI002 Mixer Black Dropped by AI002 Mixer
# Multifilter 2 (Black Panel) Dropped by Multifilter
# Multifilter 2 (Silver Panel) Dropped by Multifilter
# PM Channels (Black) Dropped by PM Channels
# Chord Organ (black panel) Dropped by Chord Organ
# Little Nerd (Magpie panel) Dropped by Little Nerd
# Sono Abitus (Silver) Dropped by Sono Abitus
# Sinc Pravus (Silver) Dropped by Sinc Pravus
# Wave Runner (Silver) Dropped by Wave Runner
# Disting mk4 (Rubadub Special Edition) Dropped by Disting mk4
# Disting mk4 Special Edition Silver Panel Dropped by Disting mk4
# Radio Music (Black Panel) Dropped by Radio Music
# Terci Ruina (Silver) Dropped by Terci Ruina
# JUST FRIENDS (v2-Gold Clouds) Dropped by JUST FRIENDS
# Modular Solo BLACK Dropped by Modular Solo
# UNICORN BOOM [limited edition] Dropped by UNICORN BOOM
# Mutant Brain silver Dropped by Mutant Brain
# Triple Sloth white panel Dropped by Triple Sloth
# Triple Sloth V2 - Magpie white panel Dropped by Triple Sloth
# WAV Recorder - Black Panel Dropped by WAV Recorder
# Roucha Legio (Silver) Dropped by Roucha Legio
# Lunar Module (Silver Panel) Dropped by Lunar Module
# Tonus VCF r2 (Black Panel Version) Dropped by TONUS VCF r2
# Univer Inter (Silver) Dropped by Univer Inter
# Librae Legio (Silver) Dropped by Librae Legio
# Trigger Riot (WHITE) Dropped by Trigger Riot
# Trigger Riot (BLACK) Dropped by Trigger Riot
# Launch Codes (New Panel) Dropped by Launch Codes
# Ruina Versio (Silver) Dropped by Ruina Versio
# Extra Mullet (Black) Dropped by Extra Mullet
# Panharmonium (black) Dropped by Panharmonium
# Sommateur X6 Black Edition Dropped by Sommateur X6
# Dust of Time Black Dropped by Dust of Time
# KS-20 Filter (Vintagelavalamp Black Panel) Dropped by KS-20 Filter
# Ostankino II (black panel) Dropped by Ostankino II
# Skorn da Bask - Black panel Dropped by Skorn da Bask
# Buffered Mult - Black Panel Dropped by Buffered Mult
# Tonestar 2600 - Bitmud black panel Dropped by TONESTAR 2600
# Tonestar 8106 BLACK Dropped by TONESTAR 8106
# Yester Versio (Silver) Dropped by Yester Versio
# Angle Grinder (Black) Dropped by Angle Grinder
# Sweet Sixteen (alternate panels) Dropped by Sweet Sixteen
# Antumbra Cara (White & Gold) Dropped by Antumbra CARA
# Subharmonicon (2020 edition) Dropped by Subharmonicon
# VnIcursal VCA(Soulless panel) Dropped by VnIcursal VCA
# VnIcursal VCA (Classic Panel) Dropped by VnIcursal VCA
# Pons Asinorum (Black) Dropped by Pons Asinorum
# Fractio Solum (Silver) Dropped by Fractio Solum
# Integra Solum (Black) Dropped by Integra Solum
# Stereo Dipole (Black and Gold) Dropped by Stereo Dipole
# 4x Stereo Mix_gold Dropped by 4x Stereo Mix
# 4x Stereo Mix_black Dropped by 4x Stereo Mix
# Vox Digitalis (Silver) Dropped by Vox Digitalis
# Super Sixteen (black panel) Dropped by Super Sixteen
# AI004 OTA VCF Black Dropped by AI004 OTA VCF
# Imitor Versio (Silver) Dropped by Imitor Versio
# Black MIDI-CV v2 Dropped by Black Midi-CV
# QCD Expander - Black Panel Dropped by QCD Expander:
# Buffered Mult (Black) Dropped by Buffered Mult
# Delay No More - Magpie white panel Dropped by Delay No More
# Quantus Ampla (Silver) Dropped by Quantus Ampla
# Triple Sloths V2 - Magpie Black Panel Dropped by Triple Sloths
# Voltage Block (Black Panel) Dropped by Voltage Block
# Jack Expander (black) Dropped by Jack Expander
# Entropic Doom (Silver Panel) Dropped by Entropic Doom
# Squid Salmple - Grey Dropped by Squid Salmple
# Sewastopol II (black panel) Dropped by Sewastopol II
# μTune Expander - black edition Dropped by μTune Expander
# μTune Expander - silver edition Dropped by μTune Expander
# Geiger Counter (Black Panel) Dropped by Geiger Counter
# Drum Sequencer with Black Keys Dropped by Drum Sequencer
# FINALISER R-EQ (Silver) Dropped by FINALISER R-EQ
# GRAINY CLAMPIT (Black Edition) Dropped by GRAINY CLAMPIT
# Lacrima Versio (Silver) Dropped by Lacrima Versio
# Tropical Noise NEO V3 black Dropped by Tropical Noise
# Melotus Versio (silver) Dropped by Melotus Versio
# AI001 Multiple Black Dropped by AI001 Multiple
# Black Quad VCA2 Dropped by Black Quad VCA
# Manis Iteritas (Black) Dropped by Manis Iteritas
# Black Mixer/Splitter Dropped by Mixer/Splitter
# E300 Ultra VCO (black panel) Dropped by E300 Ultra VCO
# Electus Versio (Silver) Dropped by Electus Versio
# Horologic Uter (Black) Dropped by Horologic Uter
# Fold Processor (BLACK) Dropped by Fold Processor
# CS019 Sample + Noise (Revised Panel) Dropped by Sample + Noise
# Desmodus Versio (Silver) Dropped by Desmodus Versio
# LIQUID GLITCHER ultraviolence oscillator gold edition Dropped by LIQUID GLITCHER
# Mutant Hot Glue (black) Dropped by Mutant Hot Glue
# Leaves Expander (Black Panel) Dropped by Leaves Expander
# Cursus Iteritas (Black) Dropped by Cursus Iteritas
# Sport Modulator 2 (both panels) Dropped by Sport Modulator
# E-110 5-Band EQ Alternative Black Panel Dropped by E-110 5-band EQ
# 10HP Mini O_C_D Matt Black with Gold Dropped by 10HP Mini O_C_D
# Mimetic Sequent (Black) Dropped by Mimetic Sequent
# Virt Iter Legio (Silver) Dropped by Virt Iter Legio
# Cockpit 2 (black) Dropped by Cockpit (black)
# Quaid Megaslope - Grey Dropped by Quaid Megaslope
# Horologic Solum (Black) Dropped by Horologic Solum
# 3x Stereo Mixer - black Dropped by 3x Stereo Mixer
# Cockpit 2 (golden) Dropped by Cockpit (golden)
# Grey+Pink Pamela’s NEW Workout Dropped by Pamela's Workout
# Vector Sequencer (black) Dropped by Vector Sequencer
# CHAOS DIVIDER HV - Sacrament Edition Dropped by CHAOS DIVIDER HV
# G-110 Noise Gate (Black Panel) Dropped by G-110 Noise Gate
# D-333 ROM Player (Red Panel) Dropped by D-333 ROM Player
# D-333 ROM Player (Black Panel) Dropped by D-333 ROM Player
# "РИТМИКС"  black (rainbow) Dropped by "РИТМИКС"  black
# Integra Funkitus (Black) Dropped by Integra Funkitus
# Variant expander (black) Dropped by Variant expander
# Quantus Trajecta (Silver) Dropped by Quantus Trajecta
# Zularic Repetitor (Black) Dropped by Zularic Repetitor
# Performance Mixer (black) Dropped by Performance mixer
# Quad Pingable LFO - Black Dropped by Quad Pingable LFO
# Cellular Automata (black panel) Dropped by Cellular Automata
# Cellular Automata (white panel) Dropped by Cellular Automata
# Mimetic Digitalis (Black) Dropped by Mimetic Digitalis
# Ataraxic Iteritas (Black) Dropped by Ataraxic Iteritas
# Polydactyl Versio (Silver) Dropped by Polydactyl Versio
# Confundo Funkitus (Black) Dropped by Confundo Funkitus
# Permutation (6hp black) Dropped by Permutation (6hp)
# Loquelic Iteritas (Black) Dropped by Loquelic Iteritas
# Numeric Repetitor (Black) Dropped by Numeric Repetitor
# Tapographic Delay - Black Panel Dropped by Tapographic Delay
# Quantum Rainbow 2 (Black and Gold Edition) Dropped by Quantum Rainbow 2
# Circadian Rhythms (BLACK) Dropped by Circadian Rhythms
# Hyperchaos Deluxe - Magpie black panel Dropped by Hyperchaos Deluxe
# SCM - Shuffling Clock Multiplier v2 (Black Panel) Dropped by SCM - Black Panel
# Interstellar Radio (Black Panel) Dropped by Interstellar Radio
# Black CV Processor V2 Dropped by Black CV Processor
# Permutation (18hp black) Dropped by Permutation (18hp)
# Atari Punk Console (black panel) Dropped by Atari Punk Console
# Atari Punk Console (alternative panel) Dropped by Atari Punk Console
# Big Honking Button (black panel) Dropped by Big Honking Button
# Encephalo Adjuster - Magpie white panel Dropped by Encephalo Adjuster
# Variatic Erumption (Black) Dropped by Variatic Erumption
# Bindubba Sequencer (black panel) Dropped by Bindubba Sequencer
# Triple Bipolar VCA (BLACK) Dropped by Triple Bipolar VCA
# Permutation (12hp black) Dropped by Permutation (12hp)
# A Plague of Demons - Magpie white panel Dropped by A Plague of Demons
# More Video-IO Grey/Black Dropped by More Video-IO Grey
# Typhoon - Black aluminum Dropped by Typhoon (aluminum)
# Continuum Phaser II  (silver) Dropped by Continuum Phaser II
# RCDBO - Black Panel (Inc DIY Kit) Dropped by RCDBO - Black Panel
# Ian Fritz's Hypster (black panel) Dropped by Ian Fritz's Hypster
# Ian Fritz's Hypster - Magpie white panel Dropped by Ian Fritz's Hypster
# nw2s::io (balanced, black) Dropped by nw2s::io (balanced)
# Ensemble Oscillator (Black Panel) Dropped by Ensemble Oscillator
# CV Trinity Expander - Aluminum Panel Dropped by CV Trinity Expander
# Glide + Noise mk2 Dark Edition Dropped by GLIDE + NOISE (MK2)
# NERDSEQ – IO EXPANDER Grey/Black Dropped by Nerdseq IO-Expander
# 8x8 Buffered Matrix, black knobs Dropped by 8x8 Buffered Matrix
# Black Output Module v2 Dropped by Black Output Module
# Black Varishape VCO 2 Dropped by Black Varishape VCO
# Black Varishape VCO 1 Dropped by Black Varishape VCO
# Ataraxic Translatron (Black) Dropped by Ataraxic Translatron
# Ataraxic Translatron (Silver) Dropped by Ataraxic Translatron
# Turing Machine Mk II (Black) Dropped by Turing Machine Mk II
# E352 Cloud Terrarium (black panel) Dropped by E352 Cloud Terrarium
# AI016 Tape Interface Black Dropped by AI016 Tape Interface
# nw2s::o16 (balanced,black) Dropped by nw2s::o16 (balanced)
# Super Warp Generator (Tokyo 2015 limited edition) Dropped by Super Warp Generator
# Cutting Room Floor v2 (Black) Dropped by Cutting Room Floor V2
# DPO (Grayscale black panel) Dropped by DPO (Grayscale panel)
# Cirklon Euro BOB CVIO - Black Dropped by Cirklon Euro BOB CVIO
# ADDAC301 Floor Control (Black Panel) Dropped by ADDAC301 Floor Control
# ER-301: Sound Computer (Nostalgia Panel) Dropped by ER-301: Sound Computer
# Expert Sleepers ES-3 MK3 (Grayscale alternate panel) Dropped by ES-3 (Grayscale panel)
# 16n AtoVproject Rework (grey panel) Dropped by 16n AtoVproject Rework
# Multi-IO Expander Grey/Black Dropped by Multi-IO Expander Grey
# Micro Research ERD/SIR white update Dropped by Micro Research ERD/SIR
# E370 Quad Morphing VCO (black panel) Dropped by E370 Quad Morphing VCO
# E520 Hyperion Processor (black panel) Dropped by E520 Hyperion Processor
# Maths v2 (Grayscale panel) Dropped by Maths (Grayscale panel)
# Maths v2 (Grayscale black panel) Dropped by Maths (Grayscale panel)
# Maths Black Grayscale with Blue Knobs (Panel) Dropped by Maths (Grayscale panel)
# MST Stereo Output Mixer (Synthrotek Panel) Dropped by MST Stereo Output Mixer
# Cursus Iteritas Percido (Silver) Dropped by Cursus Iteritas Percido
# AI006 Stomp Box Adapter Black Dropped by AI006 Stomp Box Adapter
# Basimilus Iteritas Alter (Black) Dropped by Basimilus Iteritas Alter
# 2HP2CV USB to CV Adapter (Black Panel) Dropped by 2HP2CV USB to CV Adapter
# Rotating Clock Divider V2 (black) Dropped by Rotating Clock Divider V2
# Loquelic Iteritas Percido (Black) Dropped by Loquelic Iteritas Percido
# 4ms RCD Breakout (Grayscale panel) Dropped by 4ms RCD (Grayscale panel)
# AI010 Switching Attenuator Black Dropped by AI010 Switching Attenuator
# Mungo g0 (Grayscale panel) Dropped by Mungo d0 (Grayscale panel)
# MiniMod Sample Hold & Slew (silver edition) Dropped by MiniMod Sample Hold + Slew
# NerdSEQ CV16 Expander Black/Grey Dropped by NerdSEQ CV16 Expander Black
# µO_C micro Ornament & Crime (silver) Dropped by µO_C micro Ornament & Crime
# Sonic XV Diode Ladder Filter Silver Dropped by Sonic XV Diode Ladder Filter
# Entity Bass Drum Synthesizer (Black) Dropped by Entity Bass Drum Synthesizer
# ADDAC601 VC Fixed Filterbank (Greyface) Dropped by ADDAC601 VC Fixed Filterbank
# ADDAC206 Switching Sequencer (black) Dropped by ADDAC206 Switching Sequencer
# Neuron / Difference Rectifier — Magpie white panel Dropped by Neuron / Difference Rectifier
# Spherical wavetable Navigator WHITE Dropped by Spherical Wavetable Navigator
# MiniMod Discrete Cascaded VCA "Dark Edition" Dropped by MiniMod Discrete Cascaded VCA
# Entity Percussion Synthesizer (Black and Gold) Dropped by Entity Percussion Synthesizer
# Turing Machine - Grayscale Hybrid Panel Dropped by Turing Machine v2 hybrid panel
# ADDAC802 Quintet Mixing Console (black) Dropped by ADDAC802 Quintet Mixing Console
# AI003 Looping Envelope Generator Black Dropped by AI003 Looping Envelope Generator
# Minimod Transistor Ladder Filter "Dark Edition" Dropped by MiniMod Transistor Ladder Filter
# Turing Machine Pulses Expander (Grayscale panel) Dropped by Turing Machine Pulses expander v2
# Super Sloth Chaos (Modular Addict Panel) Dropped by Sloth Chaos (Modular Addict Panel)
# Phase Displacement Oscillator MkII (BLACK) Dropped by Phase Displacement Oscillator MkII
# MiniMod Vintage Transistor Core VCO "Dark Edition" Dropped by Minimod Vintage Transistor Core VCO
# ADDAC601 Fixed Filter Bank w/ newer specs (black) Dropped by ADDAC601 VC Fixed Filter Bank (black)
# Mutable Instruments Kinks (Grayscale panel) Dropped by Mutable Instruments Links (Grayscale panel)
# Mutable Instruments Braids (Grayscale panel) Dropped by Mutable Instruments Grids (Grayscale panel)
# ADDAC402 - 4 Voice Heuristic Rhythm Generator (custom grey) Dropped by ADDAC402 4 Voice Heuristic Rhythm Generator
# Expert Sleepers Disting MK3 (alternate panel) Dropped by Expert Sleepers Disting MK4 (alternate panel)

# %%
#drop similarity column and reorder by Racks (popularity)
df = df.drop(['Similarity'], axis=1)
df = df.sort_values(by='Racks', ascending=False)
df = df.reset_index(drop=True)

# %%
#trim dataset down to L

#L = 1000
#df = df[:L]

# %%
len(df)
# Out:
# 6950

# %%
#removing nan values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6950 entries, 0 to 6949
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          6950 non-null   object
#  1   Manufacturer  6950 non-null   object
#  2   Functions     6950 non-null   object
#  3   HP            6950 non-null   int64
#  4   Depth         5776 non-null   float64
#  5   +12V (mA)     6067 non-null   float64
#  6   -12V (mA)     5729 non-null   float64
#  7   +5V (mA)      4394 non-null   float64
#  8   Price (€)     6492 non-null   float64
#  9   Racks         6950 non-null   int64
#  10  Rating        5629 non-null   float64
#  11  Votes         6950 non-null   float64
#  12  Available     6022 non-null   object
#  13  Approved      6950 non-null   int64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 760.3+ KB

# %%
#fill na values

#find means to fill certain na values
#round to one decimal place
mean_depth = round(df['Depth'].mean(), 1)
mean_pos12 = round(df['+12V (mA)'].mean(), 1)
mean_neg12 = round(df['-12V (mA)'].mean(), 1)
mean_rating = round(df['Rating'].mean(), 2)
mean_price = round(df['Price (€)'].mean(), 1)

#create dictionary to fill na values
to_fill = {'Depth': mean_depth,
           '+12V (mA)': mean_pos12,
           '-12V (mA)': mean_neg12,
           '+5V (mA)': 0,
           'Price (€)': mean_price,
           'Rating': mean_rating,
           'Available': 'No Info'
          } 

#for the ML data set, want to remove items that have nans, so dont fill them

df = df.fillna(value=to_fill) #inlace old method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1000 non-null   object
#  1   Manufacturer  1000 non-null   object
#  2   Functions     1000 non-null   object
#  3   HP            1000 non-null   int64
#  4   Depth         1000 non-null   float64
#  5   +12V (mA)     1000 non-null   float64
#  6   -12V (mA)     1000 non-null   float64
#  7   +5V (mA)      1000 non-null   float64
#  8   Price (€)     1000 non-null   float64
#  9   Racks         1000 non-null   int64
#  10  Rating        1000 non-null   float64
#  11  Votes         1000 non-null   float64
#  12  Available     1000 non-null   object
#  13  Approved      1000 non-null   int64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 109.5+ KB

# %%
#save clearned dataset ready for analysis
#N = 1000
YEAR = 2024
df.to_csv(f"{N}_most_popular_eurorack_modules_{YEAR}.csv")
